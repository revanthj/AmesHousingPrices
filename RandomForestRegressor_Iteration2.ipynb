# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
# %matplotlib inline
np.set_printoptions(precision=2)
pd.set_option('precision', 2)
np.set_printoptions(suppress=True)
sns.set(style='whitegrid')

# %%
train_path = 'data/train.csv'
test_path = 'data/test.csv'
train_data = pd.read_csv(train_path, index_col='Id')
test_data = pd.read_csv(test_path, index_col='Id')
features = train_data.iloc[:,:-1]
target = train_data.loc[:, ['SalePrice']]
print('Train Set Size : ', train_data.shape)
print('Test Set Size : ', test_data.shape)
print('Train Features Size : ', features.shape)
num_train_rows = train_data.shape[0]
num_test_rows = test_data.shape[0]
print('Train Rows : ', num_train_rows)
print('Test Rows : ', num_test_rows)
all_data = pd.concat((features, test_data)).reset_index(drop=True)
# Out:
# Train Set Size :  (1460, 80)
# Test Set Size :  (1459, 79)
# Train Features Size :  (1460, 79)
# Train Rows :  1460
# Test Rows :  1459

# %%
# Missing Data
null_features = all_data.columns[all_data.isnull().any()]
missing_ratio = (all_data[null_features].isnull().sum()/len(all_data)) * 100
missing_data = pd.DataFrame({'Missing Ratio' :missing_ratio})
print(missing_data.sort_values(by='Missing Ratio',ascending=False))


for col in ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu']:
    all_data[col] = all_data[col].fillna('None')

for col in ['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'MasVnrType']:
    all_data[col] = all_data[col].fillna('None')
    
for col in ['BsmtExposure', 'BsmtFinType2', 'BsmtQual', 'BsmtCond', 'BsmtFinType1']:
    all_data[col] = all_data[col].fillna('None')

'''
No GarageYrBlt means no Garage. We can impute mean/median since it would 
incorrectly convey existence of Garage. same reasoning for MasVnrArea.
'''
for col in ['GarageYrBlt', 'MasVnrArea']:
    all_data[col] = all_data[col].fillna(0)

'''
Group data by neighborhood & imputed null LotFrontage columns with median of
grouped data.
'''
all_data['LotFrontage'] = all_data.groupby(['Neighborhood'])\
                    ['LotFrontage'].transform(lambda x : x.fillna(x.median()))
    
all_data['Electrical'] = \
    all_data['Electrical'].fillna(all_data['Electrical'].mode()[0])
    
all_data['MSZoning'] = \
    all_data['MSZoning'].fillna(all_data['MSZoning'].mode()[0])
    
all_data['Utilities'] = all_data['Utilities'].fillna('ELO')

all_data['Exterior1st'] = all_data['Exterior1st'].fillna('Other')

all_data['Exterior2nd'] = all_data['Exterior2nd'].fillna('Other')

all_data['SaleType'] = all_data['SaleType'].fillna('Oth')

all_data['Functional'] = \
    all_data['Functional'].fillna(all_data['Functional'].mode()[0])

all_data['KitchenQual'] = \
    all_data['KitchenQual'].fillna(all_data['KitchenQual'].mode()[0])

for col in ['BsmtFullBath', 'BsmtHalfBath', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'GarageCars', 'GarageArea']:
    all_data[col] = all_data[col].fillna(0)
    
null_features = all_data.columns[all_data.isnull().any()]
missing_ratio = (all_data[null_features].isnull().sum()/len(all_data)) * 100
missing_data = pd.DataFrame({'Missing Ratio' :missing_ratio})
print(missing_data.sort_values(by='Missing Ratio',ascending=False))
# Out:
#               Missing Ratio
# PoolQC                99.66
# MiscFeature           96.40
# Alley                 93.22
# Fence                 80.44
# FireplaceQu           48.65
# LotFrontage           16.65
# GarageFinish           5.45
# GarageQual             5.45
# GarageCond             5.45
# GarageYrBlt            5.45
# GarageType             5.38
# BsmtExposure           2.81
# BsmtCond               2.81
# BsmtQual               2.77
# BsmtFinType2           2.74
# BsmtFinType1           2.71
# MasVnrType             0.82
# MasVnrArea             0.79
# MSZoning               0.14
# BsmtFullBath           0.07
# BsmtHalfBath           0.07
# Functional             0.07
# Utilities              0.07
# GarageArea             0.03
# GarageCars             0.03
# Electrical             0.03
# KitchenQual            0.03
# TotalBsmtSF            0.03
# BsmtUnfSF              0.03
# BsmtFinSF2             0.03
# BsmtFinSF1             0.03
# Exterior2nd            0.03
# Exterior1st            0.03
# SaleType               0.03
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []

# %%
all_data = pd.get_dummies(all_data)
all_data.insert(0, 'intercept', np.ones((2919,1)))
train_fmt_set = all_data[:num_train_rows]
test_fmt_set = all_data[num_train_rows:]

from sklearn.cross_validation import train_test_split
X_train , X_test, y_train, y_test = train_test_split(train_fmt_set, target, test_size=0.4, random_state=0)

print(X_train.shape)
print(X_test.shape)
# Out:
# (876, 305)
# (584, 305)
# c:\users\revan\appdata\local\programs\python\python36\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn.ensemble import RandomForestRegressor
#regressor = RandomForestRegressor(n_estimators=100, random_state=0, max_depth=6, min_samples_split=0.03, min_samples_leaf=0.01, max_features = 8)
regressor = RandomForestRegressor(random_state=0)
regressor.fit(X_train, y_train)

from sklearn import metrics
y_train_predict = regressor.predict(X_test)
print('Baseline MAE',metrics.mean_absolute_error(y_test, y_train_predict))
print('Baseline MSE',metrics.mean_squared_error(y_test, y_train_predict))
print('Baseline RMSE',np.sqrt(metrics.mean_squared_error(y_test, y_train_predict)))
print('Baseline RMSLE',np.sqrt(metrics.mean_squared_log_error(y_test, y_train_predict)))
print("Baseline Accuracy --> ", regressor.score(X_test, y_test)*100)
# Out:
# Baseline MAE 18410.816952054793
# Baseline MSE 1161134433.2011473
# Baseline RMSE 34075.42271492971
# Baseline RMSLE 0.14834845772945354
# Baseline Accuracy -->  81.36144924997993
# c:\users\revan\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.

# %%
#Gather Feature Importance
importances_list = list(regressor.feature_importances_)
features_nms = list(X_train.columns)

feature_importances = [(feature, imp) for feature, imp \
                      in zip(features_nms, importances_list)]

feature_importances = sorted(feature_importances, key = lambda x: x[1], \
                             reverse = True)

[print('Variable: {:20} Importance: {}'.format(*pair)) \
     for pair in feature_importances]
# Out:
# Variable: OverallQual          Importance: 0.5337920656972814
# Variable: GrLivArea            Importance: 0.13513545337420155
# Variable: GarageArea           Importance: 0.03154883105208202
# Variable: MasVnrArea           Importance: 0.03078319672122231
# Variable: TotalBsmtSF          Importance: 0.02954328218357628
# Variable: YearBuilt            Importance: 0.0287914118741373
# Variable: BsmtFinSF1           Importance: 0.02081466599277871
# Variable: MoSold               Importance: 0.01667271798719229
# Variable: LotArea              Importance: 0.01569666086840537
# Variable: 1stFlrSF             Importance: 0.015380427616524459
# Variable: LotFrontage          Importance: 0.01205302195851105
# Variable: ExterQual_Gd         Importance: 0.008830701254068835
# Variable: Exterior2nd_HdBoard  Importance: 0.007414402302008287
# Variable: BsmtUnfSF            Importance: 0.007373985699373133
# Variable: YearRemodAdd         Importance: 0.006253397936669208
# Variable: GarageYrBlt          Importance: 0.005375444658758307
# Variable: 2ndFlrSF             Importance: 0.004882189959791155
# Variable: CentralAir_Y         Importance: 0.004825021789701439
# Variable: Fireplaces           Importance: 0.00425617268032291
# Variable: OverallCond          Importance: 0.004237452163926703
# Variable: WoodDeckSF           Importance: 0.003927696560842934
# Variable: OpenPorchSF          Importance: 0.0038007718174911283
# Variable: Neighborhood_Edwards Importance: 0.003655258935569384
# Variable: CentralAir_N         Importance: 0.003458797091149996
# Variable: TotRmsAbvGrd         Importance: 0.0034418273347867068
# Variable: GarageType_Attchd    Importance: 0.0033411532433873644
# Variable: GarageCars           Importance: 0.0032323272123189507
# Variable: BedroomAbvGr         Importance: 0.003231957042758989
# Variable: KitchenQual_Gd       Importance: 0.0025445144792167287
# Variable: BldgType_1Fam        Importance: 0.0015765439186832993
# Variable: LandContour_Bnk      Importance: 0.0013897392830948191
# Variable: BsmtExposure_No      Importance: 0.0012634474451310178
# Variable: HalfBath             Importance: 0.00124790872847327
# Variable: MSSubClass           Importance: 0.0012421602004080293
# Variable: MSZoning_RM          Importance: 0.0011681515968776947
# Variable: MasVnrType_Stone     Importance: 0.001132462131619009
# Variable: LotShape_IR2         Importance: 0.0010780589696082732
# Variable: RoofStyle_Hip        Importance: 0.0010735415997074308
# Variable: RoofStyle_Gable      Importance: 0.00107175440739962
# Variable: YrSold               Importance: 0.001055194155933304
# Variable: KitchenQual_TA       Importance: 0.001053190159967953
# Variable: LotShape_Reg         Importance: 0.001025195496608022
# Variable: BsmtQual_Ex          Importance: 0.0009105611178273684
# Variable: BsmtQual_Gd          Importance: 0.0008937940037193112
# Variable: Condition1_PosN      Importance: 0.0007907889846385047
# Variable: SaleCondition_Partial Importance: 0.0007793434064910214
# Variable: FullBath             Importance: 0.0007668165813058849
# Variable: MSZoning_C (all)     Importance: 0.0007194903194381954
# Variable: LotConfig_CulDSac    Importance: 0.0007157694605580322
# Variable: Neighborhood_NoRidge Importance: 0.0006976632265166926
# Variable: LotConfig_Inside     Importance: 0.0006846209625849837
# Variable: ExterQual_TA         Importance: 0.0006717796683342879
# Variable: BsmtFinSF2           Importance: 0.0006449703946172648
# Variable: BsmtFinType1_Rec     Importance: 0.0006164888727471036
# Variable: FireplaceQu_None     Importance: 0.0005968320751762174
# Variable: Neighborhood_StoneBr Importance: 0.0005850730899046982
# Variable: KitchenQual_Ex       Importance: 0.0005637317336449462
# Variable: BsmtExposure_Gd      Importance: 0.0005492220882276133
# Variable: GarageFinish_Fin     Importance: 0.0005485694074319458
# Variable: Neighborhood_Crawfor Importance: 0.0005363160059822911
# Variable: BsmtFinType1_GLQ     Importance: 0.000514232008686732
# Variable: Exterior2nd_VinylSd  Importance: 0.0004907096184425396
# Variable: BsmtHalfBath         Importance: 0.00047244021004791143
# Variable: Functional_Typ       Importance: 0.0004541303508787616
# Variable: FireplaceQu_Gd       Importance: 0.00044713361725589804
# Variable: RoofMatl_CompShg     Importance: 0.0004449220846842591
# Variable: GarageFinish_Unf     Importance: 0.00043865314458507823
# Variable: BsmtFullBath         Importance: 0.0004339085229645264
# Variable: SaleType_New         Importance: 0.0004271828586174881
# Variable: Neighborhood_NAmes   Importance: 0.00042464131710394804
# Variable: GarageFinish_RFn     Importance: 0.0004113544314408071
# Variable: RoofStyle_Flat       Importance: 0.00040502760287007414
# Variable: HeatingQC_Ex         Importance: 0.00040131795661062187
# Variable: FireplaceQu_Ex       Importance: 0.00040102823453340734
# Variable: BsmtCond_TA          Importance: 0.00039105074894234954
# Variable: Neighborhood_IDOTRR  Importance: 0.00033315844159168955
# Variable: LandSlope_Gtl        Importance: 0.00030869894314901407
# Variable: GarageQual_TA        Importance: 0.00030109232313175566
# Variable: BldgType_TwnhsE      Importance: 0.0002908316718023446
# Variable: Neighborhood_Somerst Importance: 0.0002907851940912361
# Variable: MasVnrType_None      Importance: 0.0002790250148940362
# Variable: LandContour_Lvl      Importance: 0.0002788428512773076
# Variable: Exterior1st_WdShing  Importance: 0.00023844825195753626
# Variable: BsmtExposure_Av      Importance: 0.00023549643660908075
# Variable: HeatingQC_TA         Importance: 0.00021502631458438312
# Variable: SaleCondition_Normal Importance: 0.00021031644552839445
# Variable: FireplaceQu_TA       Importance: 0.00020933461262709075
# Variable: Foundation_CBlock    Importance: 0.00020600392090180543
# Variable: SaleCondition_Abnorml Importance: 0.00019394694384130607
# Variable: LandContour_HLS      Importance: 0.00019228498151414812
# Variable: LowQualFinSF         Importance: 0.00019167880657728866
# Variable: LandSlope_Sev        Importance: 0.00016994823724907011
# Variable: ExterCond_TA         Importance: 0.0001659650283262559
# Variable: Neighborhood_Timber  Importance: 0.00016530316800202746
# Variable: EnclosedPorch        Importance: 0.00016443971744112206
# Variable: Exterior2nd_Wd Sdng  Importance: 0.0001633703804713976
# Variable: BsmtExposure_Mn      Importance: 0.00016142493934831898
# Variable: GarageType_2Types    Importance: 0.0001576099789102221
# Variable: MSZoning_RL          Importance: 0.00015559786510070203
# Variable: BsmtFinType2_Unf     Importance: 0.00015325042645930592
# Variable: Exterior1st_Plywood  Importance: 0.00015266401767541883
# Variable: GarageCond_TA        Importance: 0.000150744424763133
# Variable: Exterior1st_VinylSd  Importance: 0.00014917073626747427
# Variable: LotShape_IR1         Importance: 0.00014673029344012455
# Variable: BsmtFinType1_None    Importance: 0.00014576241237918174
# Variable: Condition1_Norm      Importance: 0.0001450411629839426
# Variable: Electrical_SBrkr     Importance: 0.000143586975766259
# Variable: HeatingQC_Fa         Importance: 0.0001407509166164443
# Variable: HouseStyle_2Story    Importance: 0.00014024013511513444
# Variable: GarageType_Detchd    Importance: 0.00013351357173815046
# Variable: Neighborhood_SawyerW Importance: 0.00013326129076394558
# Variable: Exterior2nd_Plywood  Importance: 0.0001299730048005311
# Variable: Exterior1st_BrkComm  Importance: 0.00012784291004756015
# Variable: ExterCond_Fa         Importance: 0.000126054641064609
# Variable: Fence_GdWo           Importance: 0.00012409400967349995
# Variable: BsmtExposure_None    Importance: 0.00011370472141227822
# Variable: BsmtFinType1_BLQ     Importance: 0.00011066167490774777
# Variable: Exterior1st_Wd Sdng  Importance: 0.0001101263508462138
# Variable: BsmtQual_TA          Importance: 0.00010684199425112233
# Variable: HeatingQC_Gd         Importance: 0.00010624743804111354
# Variable: BsmtFinType1_Unf     Importance: 0.00010622372060680712
# Variable: PavedDrive_Y         Importance: 0.0001039569342862436
# Variable: Neighborhood_OldTown Importance: 0.00010290254154503298
# Variable: SaleType_WD          Importance: 0.00010041823562790986
# Variable: Neighborhood_NridgHt Importance: 9.949970264793127e-05
# Variable: ScreenPorch          Importance: 9.229986046410611e-05
# Variable: MasVnrType_BrkFace   Importance: 9.172071964486508e-05
# Variable: LotConfig_FR2        Importance: 9.167861261182662e-05
# Variable: PavedDrive_N         Importance: 9.074388095317416e-05
# Variable: FireplaceQu_Po       Importance: 8.989838449502432e-05
# Variable: Functional_Maj2      Importance: 8.984848758878553e-05
# Variable: Exterior1st_MetalSd  Importance: 8.394748750545277e-05
# Variable: BsmtFinType1_ALQ     Importance: 8.299191639263129e-05
# Variable: BldgType_Twnhs       Importance: 8.189845775631668e-05
# Variable: HouseStyle_1Story    Importance: 8.143679432875934e-05
# Variable: RoofMatl_Tar&Grv     Importance: 7.818255959704466e-05
# Variable: LandSlope_Mod        Importance: 7.6295022864053e-05
# Variable: RoofMatl_WdShngl     Importance: 6.117534822796808e-05
# Variable: Exterior2nd_CmentBd  Importance: 5.977261984539217e-05
# Variable: BsmtQual_Fa          Importance: 5.878420836226819e-05
# Variable: Neighborhood_Mitchel Importance: 5.749263759796418e-05
# Variable: Exterior1st_HdBoard  Importance: 5.671003534568108e-05
# Variable: Exterior2nd_Wd Shng  Importance: 5.5677846367768204e-05
# Variable: HouseStyle_1.5Fin    Importance: 5.407086537603005e-05
# Variable: Foundation_PConc     Importance: 5.336065406271926e-05
# Variable: KitchenAbvGr         Importance: 5.025837101156575e-05
# Variable: LotConfig_Corner     Importance: 4.974891052762358e-05
# Variable: ExterQual_Fa         Importance: 4.785019589149745e-05
# Variable: 3SsnPorch            Importance: 4.719684410394516e-05
# Variable: Functional_Min2      Importance: 4.6579727683870466e-05
# Variable: Neighborhood_BrkSide Importance: 4.646956626060316e-05
# Variable: BsmtFinType1_LwQ     Importance: 4.5583011346500197e-05
# Variable: Exterior2nd_MetalSd  Importance: 4.5302176078173784e-05
# Variable: Neighborhood_ClearCr Importance: 4.412867064719593e-05
# Variable: ExterCond_Ex         Importance: 4.272267747417569e-05
# Variable: Fence_None           Importance: 4.144764110996481e-05
# Variable: Exterior2nd_Stucco   Importance: 4.019152322459777e-05
# Variable: GarageFinish_None    Importance: 3.8480481416145213e-05
# Variable: Neighborhood_CollgCr Importance: 3.805374961572034e-05
# Variable: MiscFeature_Shed     Importance: 3.58314727098848e-05
# Variable: MSZoning_FV          Importance: 3.519265732115883e-05
# Variable: ExterCond_Gd         Importance: 3.404725018910341e-05
# Variable: Condition1_RRAn      Importance: 3.384020977513192e-05
# Variable: Fence_MnPrv          Importance: 2.9973045292933316e-05
# Variable: Fence_GdPrv          Importance: 2.7480529570889386e-05
# Variable: Exterior2nd_AsbShng  Importance: 2.6784172614588204e-05
# Variable: Exterior1st_BrkFace  Importance: 2.5687558099271465e-05
# Variable: Neighborhood_Sawyer  Importance: 2.5477555998746047e-05
# Variable: Electrical_FuseA     Importance: 2.374179265223618e-05
# Variable: MiscFeature_None     Importance: 2.3004576218651382e-05
# Variable: MasVnrType_BrkCmn    Importance: 2.2535718777039644e-05
# Variable: BsmtFinType2_LwQ     Importance: 2.1707047529035795e-05
# Variable: RoofStyle_Gambrel    Importance: 2.138526702022721e-05
# Variable: SaleCondition_Family Importance: 2.0628901151933975e-05
# Variable: Exterior1st_AsbShng  Importance: 1.9658484580029037e-05
# Variable: Neighborhood_SWISU   Importance: 1.9019715173973796e-05
# Variable: Exterior2nd_ImStucc  Importance: 1.894940339492891e-05
# Variable: HouseStyle_SLvl      Importance: 1.861793492833322e-05
# Variable: KitchenQual_Fa       Importance: 1.7081654779395452e-05
# Variable: BsmtFinType2_Rec     Importance: 1.6632960789506707e-05
# Variable: MiscVal              Importance: 1.5780993676965927e-05
# Variable: Neighborhood_Gilbert Importance: 1.4209222244152447e-05
# Variable: GarageQual_Fa        Importance: 1.3785018130685109e-05
# Variable: Condition1_Feedr     Importance: 1.3050968348460088e-05
# Variable: Neighborhood_Blmngtn Importance: 1.3013993318484781e-05
# Variable: SaleType_CWD         Importance: 1.3001143689805164e-05
# Variable: Alley_Pave           Importance: 1.2302712218617226e-05
# Variable: BsmtCond_Gd          Importance: 1.1960658385337853e-05
# Variable: Exterior2nd_Stone    Importance: 1.1855231487738877e-05
# Variable: Foundation_BrkTil    Importance: 1.1784300902357262e-05
# Variable: BsmtFinType2_ALQ     Importance: 1.1319542654232442e-05
# Variable: HouseStyle_SFoyer    Importance: 1.1157497232310046e-05
# Variable: BldgType_2fmCon      Importance: 9.459652746688946e-06
# Variable: GarageType_Basment   Importance: 9.130407578215394e-06
# Variable: Exterior1st_Stucco   Importance: 8.574508891699132e-06
# Variable: Alley_Grvl           Importance: 8.544919200607914e-06
# Variable: GarageType_BuiltIn   Importance: 7.794410312803902e-06
# Variable: GarageCond_Fa        Importance: 7.52374667797816e-06
# Variable: HouseStyle_1.5Unf    Importance: 6.434909503034487e-06
# Variable: Electrical_FuseF     Importance: 6.272908410201993e-06
# Variable: Exterior1st_Stone    Importance: 5.914402619836691e-06
# Variable: GarageQual_Gd        Importance: 5.790920247671592e-06
# Variable: FireplaceQu_Fa       Importance: 5.604813565206541e-06
# Variable: BsmtFinType2_BLQ     Importance: 5.323556933526151e-06
# Variable: GarageType_CarPort   Importance: 5.259590843741689e-06
# Variable: Heating_GasA         Importance: 4.08813328106897e-06
# Variable: GarageQual_Po        Importance: 3.901488889029045e-06
# Variable: SaleType_COD         Importance: 3.512665164414036e-06
# Variable: GarageQual_None      Importance: 2.493988090667719e-06
# Variable: Condition1_RRNn      Importance: 2.3653871671700994e-06
# Variable: PoolQC_None          Importance: 2.210831953997553e-06
# Variable: SaleType_ConLD       Importance: 2.14148309820922e-06
# Variable: MSZoning_RH          Importance: 2.094701265770796e-06
# Variable: HouseStyle_2.5Unf    Importance: 1.9143615224526237e-06
# Variable: Neighborhood_Blueste Importance: 1.8482123100852612e-06
# Variable: Neighborhood_NPkVill Importance: 1.6411555231142302e-06
# Variable: Functional_Min1      Importance: 1.4524663978608591e-06
# Variable: Exterior2nd_BrkFace  Importance: 1.3638082117938708e-06
# Variable: GarageType_None      Importance: 1.3039781401736365e-06
# Variable: Neighborhood_NWAmes  Importance: 1.1868296121335513e-06
# Variable: Foundation_Slab      Importance: 9.716772644847852e-07
# Variable: GarageCond_None      Importance: 9.105886201803977e-07
# Variable: BldgType_Duplex      Importance: 7.268060765763006e-07
# Variable: PavedDrive_P         Importance: 6.334377958142213e-07
# Variable: Functional_Maj1      Importance: 6.072708711245695e-07
# Variable: Exterior1st_CemntBd  Importance: 5.950947181363481e-07
# Variable: LandContour_Low      Importance: 5.747447001409725e-07
# Variable: BsmtFinType2_GLQ     Importance: 5.397963298883382e-07
# Variable: Street_Grvl          Importance: 4.923531106575491e-07
# Variable: BsmtCond_Fa          Importance: 4.524374544596113e-07
# Variable: BsmtCond_Po          Importance: 4.20996451781612e-07
# Variable: MiscFeature_Othr     Importance: 3.830076502468344e-07
# Variable: Condition1_RRAe      Importance: 2.856731157585444e-07
# Variable: Condition2_Feedr     Importance: 2.3197763669595754e-07
# Variable: Exterior2nd_Brk Cmn  Importance: 2.1308834441422456e-07
# Variable: Condition1_Artery    Importance: 1.6180254720581191e-07
# Variable: Alley_None           Importance: 1.549778414437393e-07
# Variable: ExterQual_Ex         Importance: 1.3219501956453215e-07
# Variable: Heating_GasW         Importance: 1.1079415906334715e-07
# Variable: GarageCond_Po        Importance: 7.42328437427169e-08
# Variable: BsmtCond_None        Importance: 4.1693091239222606e-08
# Variable: SaleType_ConLw       Importance: 1.2353508515304598e-08
# Variable: LotShape_IR3         Importance: 1.1016251629957444e-08
# Variable: BsmtQual_None        Importance: 1.2353508510612727e-10
# Variable: SaleType_ConLI       Importance: 8.523533776568981e-11
# Variable: intercept            Importance: 0.0
# Variable: PoolArea             Importance: 0.0
# Variable: Street_Pave          Importance: 0.0
# Variable: Utilities_AllPub     Importance: 0.0
# Variable: Utilities_ELO        Importance: 0.0
# Variable: Utilities_NoSeWa     Importance: 0.0
# Variable: LotConfig_FR3        Importance: 0.0
# Variable: Neighborhood_BrDale  Importance: 0.0
# Variable: Neighborhood_MeadowV Importance: 0.0
# Variable: Neighborhood_Veenker Importance: 0.0
# Variable: Condition1_PosA      Importance: 0.0
# Variable: Condition1_RRNe      Importance: 0.0
# Variable: Condition2_Artery    Importance: 0.0
# Variable: Condition2_Norm      Importance: 0.0
# Variable: Condition2_PosA      Importance: 0.0
# Variable: Condition2_PosN      Importance: 0.0
# Variable: Condition2_RRAe      Importance: 0.0
# Variable: Condition2_RRAn      Importance: 0.0
# Variable: Condition2_RRNn      Importance: 0.0
# Variable: HouseStyle_2.5Fin    Importance: 0.0
# Variable: RoofStyle_Mansard    Importance: 0.0
# Variable: RoofStyle_Shed       Importance: 0.0
# Variable: RoofMatl_ClyTile     Importance: 0.0
# Variable: RoofMatl_Membran     Importance: 0.0
# Variable: RoofMatl_Metal       Importance: 0.0
# Variable: RoofMatl_Roll        Importance: 0.0
# Variable: RoofMatl_WdShake     Importance: 0.0
# Variable: Exterior1st_AsphShn  Importance: 0.0
# Variable: Exterior1st_CBlock   Importance: 0.0
# Variable: Exterior1st_ImStucc  Importance: 0.0
# Variable: Exterior1st_Other    Importance: 0.0
# Variable: Exterior2nd_AsphShn  Importance: 0.0
# Variable: Exterior2nd_CBlock   Importance: 0.0
# Variable: Exterior2nd_Other    Importance: 0.0
# Variable: ExterCond_Po         Importance: 0.0
# Variable: Foundation_Stone     Importance: 0.0
# Variable: Foundation_Wood      Importance: 0.0
# Variable: BsmtFinType2_None    Importance: 0.0
# Variable: Heating_Floor        Importance: 0.0
# Variable: Heating_Grav         Importance: 0.0
# Variable: Heating_OthW         Importance: 0.0
# Variable: Heating_Wall         Importance: 0.0
# Variable: HeatingQC_Po         Importance: 0.0
# Variable: Electrical_FuseP     Importance: 0.0
# Variable: Electrical_Mix       Importance: 0.0
# Variable: Functional_Mod       Importance: 0.0
# Variable: Functional_Sev       Importance: 0.0
# Variable: GarageQual_Ex        Importance: 0.0
# Variable: GarageCond_Ex        Importance: 0.0
# Variable: GarageCond_Gd        Importance: 0.0
# Variable: PoolQC_Ex            Importance: 0.0
# Variable: PoolQC_Fa            Importance: 0.0
# Variable: PoolQC_Gd            Importance: 0.0
# Variable: Fence_MnWw           Importance: 0.0
# Variable: MiscFeature_Gar2     Importance: 0.0
# Variable: MiscFeature_TenC     Importance: 0.0
# Variable: SaleType_Con         Importance: 0.0
# Variable: SaleType_Oth         Importance: 0.0
# Variable: SaleCondition_AdjLand Importance: 0.0
# Variable: SaleCondition_Alloca Importance: 0.0
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
#Plot Cumulative feature importance
# List of features sorted from most to least important
'''sorted_importances = [importance[1] for importance in feature_importances]
sorted_features = [importance[0] for importance in feature_importances]

# Cumulative importances
cumulative_importances = np.cumsum(sorted_importances)

plt.plot(importances_list, cumulative_importances, 'g-')

# Draw line at 95% of importance retained
plt.hlines(y = 0.95, xmin=0, xmax=len(sorted_importances), color = 'r', linestyles = 'dashed')
# Format x ticks and labels
plt.xticks(importances_list, sorted_features, rotation = 'vertical')

# Axis labels and title
plt.xlabel('Variable'); 
plt.ylabel('Cumulative Importance'); 
plt.title('Cumulative Importances');'''
# Out:
# "sorted_importances = [importance[1] for importance in feature_importances]\nsorted_features = [importance[0] for importance in feature_importances]\n\n# Cumulative importances\ncumulative_importances = np.cumsum(sorted_importances)\n\nplt.plot(importances_list, cumulative_importances, 'g-')\n\n# Draw line at 95% of importance retained\nplt.hlines(y = 0.95, xmin=0, xmax=len(sorted_importances), color = 'r', linestyles = 'dashed')\n# Format x ticks and labels\nplt.xticks(importances_list, sorted_features, rotation = 'vertical')\n\n# Axis labels and title\nplt.xlabel('Variable'); \nplt.ylabel('Cumulative Importance'); \nplt.title('Cumulative Importances');"

# %%
#Rebuild model with top 11 important parameters

all_data = all_data.loc[:,['OverallQual', 'GrLivArea', 'GarageArea',
                             'MasVnrArea', 'TotalBsmtSF', 'YearBuilt',
                             'BsmtFinSF1', 'MoSold', 'LotArea', 
                              '1stFlrSF', 'LotFrontage', 'ExterQual_Gd',
                          'Exterior2nd_HdBoard', 'BsmtUnfSF', 'YearRemodAdd',
                          'GarageYrBlt', '2ndFlrSF', 'CentralAir_Y', 'Fireplaces',
                          'OverallCond', 'WoodDeckSF', 'OpenPorchSF', 
                          'Neighborhood_Edwards']]

train_fmt_set = all_data[:num_train_rows]
test_fmt_set = all_data[num_train_rows:]

from sklearn.cross_validation import train_test_split
X_train , X_test, y_train, y_test = train_test_split(train_fmt_set, target, test_size=0.4, random_state=0)

# check whether there are any NaNs in the dataframe
#print(np.any(np.isnan(X_train)))

#If True, then find where NaNs exist
#print(np.where(np.isnan(X_train)))

regressor = RandomForestRegressor(random_state=0)
regressor.fit(X_train, y_train)

from sklearn import metrics
y_train_predict = regressor.predict(X_test)
print('Top 23 Feature MAE',metrics.mean_absolute_error(y_test, y_train_predict))
print('Top 23 Feature MSE',metrics.mean_squared_error(y_test, y_train_predict))
print('Top 23 Feature RMSE',np.sqrt(metrics.mean_squared_error(y_test, y_train_predict)))
print('Top 23 Feature RMSLE',np.sqrt(metrics.mean_squared_log_error(y_test, y_train_predict)))
print("Top 23 Feature Accuracy --> ", round(regressor.score(X_test, y_test)*100, 2))

'''
Baseline Accuracy -->  81.36
Top 11 : 77.93
Top 19 : 78.77
Top 23 : 82.56
'''
# Out:
# Top 23 Feature MAE 19023.280479452053
# Top 23 Feature MSE 1086762013.1353083
# Top 23 Feature RMSE 32966.073668778154
# Top 23 Feature RMSLE 0.1511254400767679
# Top 23 Feature Accuracy -->  82.56
# c:\users\revan\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:25: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# '\nBaseline Accuracy -->  81.36\nTop 11 : 77.93\nTop 19 : 78.77\nTop 23 : 82.56\n'

# %%
num_tree_list = np.linspace(20, 100, 9, endpoint=True, dtype=int)
max_features_list = ['auto', 'sqrt']
max_depth_list = np.linspace(4, 16, 7, endpoint=True, dtype=int)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
bootstrap = [True, False]

random_grid = {'n_estimators': num_tree_list, 
               'max_features': max_features_list, 
               'max_depth': max_depth_list, 
               'min_samples_split': min_samples_split, 
               'min_samples_leaf': min_samples_leaf, 
               'bootstrap': bootstrap}

from sklearn.model_selection import RandomizedSearchCV
random_regr = RandomForestRegressor()
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
#rf_random = RandomizedSearchCV(estimator = random_regr, 
                param_distributions = random_grid, 
                n_iter = 100, cv = 3, verbose=2, 
                random_state=0, n_jobs = -1)
#rf_random.fit(X_train, y_train)
#print(rf_random.best_params_)

'''
Best Model:
-----------
{'n_estimators': 70, 
'min_samples_split': 2, 
'min_samples_leaf': 1, 
'max_features': 'sqrt', 
'max_depth': 10, 
'bootstrap': False}
'''

# %%
regressor = RandomForestRegressor(random_state=0, n_estimators=70,
                        min_samples_split=2, min_samples_leaf=1, max_features='sqrt',
                        max_depth=10, bootstrap=False)
regressor.fit(X_train, y_train)

from sklearn import metrics
y_train_predict = regressor.predict(X_test)
print('Best Random Fit MAE',metrics.mean_absolute_error(y_test, y_train_predict))
print('Best Random Fit MSE',metrics.mean_squared_error(y_test, y_train_predict))
print('Best Random Fit RMSE',np.sqrt(metrics.mean_squared_error(y_test, y_train_predict)))
print('Best Random Fit RMSLE',np.sqrt(metrics.mean_squared_log_error(y_test, y_train_predict)))
print("Best Random Fit Accuracy --> ", round(regressor.score(X_test, y_test)*100, 2))
# Out:
# Best Random Fit MAE 17783.949537480927
# Best Random Fit MSE 1033916943.7638636
# Best Random Fit RMSE 32154.578892653277
# Best Random Fit RMSLE 0.14174874073623517
# Best Random Fit Accuracy -->  83.4
# c:\users\revan\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.

# %%
param_grid = {'n_estimators': [50,60,80,90], 
              'min_samples_split': [2, 3, 4], 
              'min_samples_leaf': [1, 2, 3], 
              'max_features': [4, 5, 6], 
              'max_depth': [8, 9, 10, 11], 
              'bootstrap': [False]}

# Create a based model
rf = RandomForestRegressor()
# Instantiate the grid search model
#from sklearn.model_selection import GridSearchCV
#grid_regr = GridSearchCV(estimator = rf, param_grid = param_grid, cv = 3, n_jobs = -1, verbose = 2)

#grid_regr.fit(X_train, y_train)
print(grid_regr.best_params_)

'''Best Model:
-----------
{'bootstrap': False, 
'max_depth': 11, 
'max_features': 5, 
'min_samples_leaf': 1, 
'min_samples_split': 4, 
'n_estimators': 90}'''

# %%
regressor = RandomForestRegressor(random_state=0, n_estimators=90,
                        min_samples_split=4, min_samples_leaf=1, max_features=5,
                        max_depth=11, bootstrap=False)
regressor.fit(X_train, y_train)

from sklearn import metrics
y_train_predict = regressor.predict(X_test)
print('Best GridSearchCV Fit MAE',metrics.mean_absolute_error(y_test, y_train_predict))
print('Best GridSearchCV Fit MSE',metrics.mean_squared_error(y_test, y_train_predict))
print('Best GridSearchCV Fit RMSE',np.sqrt(metrics.mean_squared_error(y_test, y_train_predict)))
print('Best GridSearchCV Fit RMSLE',np.sqrt(metrics.mean_squared_log_error(y_test, y_train_predict)))
print("Best GridSearchCV Fit Accuracy --> ", round(regressor.score(X_test, y_test)*100, 2))


'''
Best GridSearchCV Fit Accuracy -->  85.83
Best RandomSearchCV Fit Accuracy -->  86.22

So, lets go with Random Search CV Best Fit Params
{'n_estimators': 70, 
'min_samples_split': 2, 
'min_samples_leaf': 1, 
'max_features': 'sqrt', 
'max_depth': 10, 
'bootstrap': False}
'''
# Out:
# Best Random Fit MAE 17174.191466211432
# Best Random Fit MSE 882943835.7111392
# Best Random Fit RMSE 29714.370861775606
# Best Random Fit RMSLE 0.13398974445965578
# Best Random Fit Accuracy -->  85.83
# c:\users\revan\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
